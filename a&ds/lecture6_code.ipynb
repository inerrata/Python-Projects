# %%
def selection_sort(array):
    """ Complexity: O(n^2)"""
    n = len(array)
    for i in range(n-1):
        # Assume the first unsorted element is the minimum
        min_idx = i
        
        # Go through the whole array to find smallest
        for j in range(i+1, n):
            if array[j] < array[min_idx]:
                min_idx = j
        
        array[i], array[min_idx] = array[min_idx], array[i]
    return array

# %%
def bubble_sort(array):
    """ Complexity: O(n^2)"""
    n = len(array)
    for i in range(n):
        swapped = False
        
        for j in range(0, n-i-1):
            if array[j] > array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
                swapped = True
        
        if not swapped:
            break

# %%
def evaluate_poly(a, x):
    evaluation = a[0]
    power = 1
    n = len(a) # how many terms are there?
    for i in range(1, n):
        power *= x 
        evaulation += a[1] * power
    return evaluation

"""
Ex: a = [2,3,5], x = 2
evaluation = 2
First loop:
1 * 2 = 2, then evaluation = 2 + (3 * 2)
"""
