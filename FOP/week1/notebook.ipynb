# %%
base = 10
inc = 7
ex = -5
offset = 3

base, inc, ex, offset
# Out:
# (10, 7, -5, 3)

# %%
calc1 = base + inc
calc1
# Out:
# 5

# %%
calc2 = base**ex
calc2
# Out:
# 1e-05

# %%
diff = abs(calc1 - calc2)
diff
# Out:
# 4.99999
